# %%
import sys
from temgymbasic.model import (
    Model,
)
from temgymbasic import components as comp
import matplotlib.pyplot as plt
from PySide6.QtWidgets import QApplication
from temgymbasic.gui import TemGymWindow

import numpy as np
from temgymbasic.utils import calculate_phi_0
from temgymbasic import gbd

from typing import Tuple, NamedTuple
from temgymbasic.plotting import plot_model
# %matplotlib ipympl

# %%
n_rays = 100
wavelength = 0.001
k = 2 * np.pi / wavelength
pupil_radius = 0.0

wavelengths = np.full(n_rays, wavelength)

object_plane = 0.0
lens_plane = 0.3
image_plane = 1.0
focal_length = 0.2

size = 256
det_shape = (size, size)
pixel_size = 0.5 / size
dsize = det_shape[0] * pixel_size

x_det = np.linspace(-dsize / 2, dsize / 2, size)

theta_x = 0
theta_y = 0

deg_yx = np.deg2rad((theta_y, theta_x ))
tilt_yx = np.tan(deg_yx)

wo = wavelength * 10

wos = np.full(n_rays, wo)

div = wavelength / (np.pi * wo)

dPx = wo
dPy = wo
dHx = div
dHy = div

z_r = (np.pi * wo ** 2) / wavelengths

coeffs = [0.0, 0.0, , 0, 0]

z = lens_plane
z1 = lens_plane
z2 = image_plane - lens_plane

# %%
components = (
    comp.PointBeam(
        z=object_plane,
        voltage=calculate_phi_0(wavelength),
        semi_angle = 0.1,
        xy_offset=(0.2, 0.0),
    ),
    # comp.ParallelBeam(
    #     xy_offset=(0.0, 0),
    #     z=object_plane,
    #     voltage=calculate_phi_0(wavelength),
    #     radius = 0.1
    # ),
    comp.AberratedLens(
        z = lens_plane,
        z1 = object_plane - lens_plane,
        z2 = image_plane - lens_plane,
        f = focal_length,
        name='Aberrated Lens',
        coeffs=coeffs
    ),
    comp.AccumulatingDetector(
        z=image_plane,
        pixel_size=pixel_size,
        shape=det_shape,
        buffer_length=1,
        interference='ray',
    ),
)

# %%
model = Model(components)
all_rays_aber_lens = tuple(model.run_iter(num_rays=n_rays))

#Insert the rays to the left of the lens into the tuple of all rays
all_rays_aber_lens = all_rays_aber_lens[:1] + (model.run_to_z(num_rays=n_rays, z=lens_plane),) + all_rays_aber_lens[1:]
xvals = np.stack(tuple(r.x for r in all_rays_aber_lens), axis=0)
zvals = np.asarray(tuple(r.z for r in all_rays_aber_lens))

# %%
plt.figure()
plt.plot(zvals, xvals)
# Out:
# [<matplotlib.lines.Line2D at 0x7f84293cef10>,
#  <matplotlib.lines.Line2D at 0x7f84293cd5d0>,
#  <matplotlib.lines.Line2D at 0x7f84293cf250>,
#  <matplotlib.lines.Line2D at 0x7f8429657510>,
#  <matplotlib.lines.Line2D at 0x7f84293cf990>,
#  <matplotlib.lines.Line2D at 0x7f84293cfb90>,
#  <matplotlib.lines.Line2D at 0x7f84293cff90>,
#  <matplotlib.lines.Line2D at 0x7f8429301e50>,
#  <matplotlib.lines.Line2D at 0x7f84293606d0>,
#  <matplotlib.lines.Line2D at 0x7f84293cfcd0>,
#  <matplotlib.lines.Line2D at 0x7f84293d8dd0>,
#  <matplotlib.lines.Line2D at 0x7f84293b9110>,
#  <matplotlib.lines.Line2D at 0x7f84295c9490>,
#  <matplotlib.lines.Line2D at 0x7f84293d9710>,
#  <matplotlib.lines.Line2D at 0x7f84293d9bd0>,
#  <matplotlib.lines.Line2D at 0x7f8429371f50>,
#  <matplotlib.lines.Line2D at 0x7f84293da1d0>,
#  <matplotlib.lines.Line2D at 0x7f84295ca650>,
#  <matplotlib.lines.Line2D at 0x7f84293da8d0>,
#  <matplotlib.lines.Line2D at 0x7f842937ad50>,
#  <matplotlib.lines.Line2D at 0x7f84293dafd0>,
#  <matplotlib.lines.Line2D at 0x7f84293db490>,
#  <matplotlib.lines.Line2D at 0x7f84293737d0>,
#  <matplotlib.lines.Line2D at 0x7f84293dbb50>,
#  <matplotlib.lines.Line2D at 0x7f8429303ed0>,
#  <matplotlib.lines.Line2D at 0x7f84293dc190>,
#  <matplotlib.lines.Line2D at 0x7f84293dc550>,
#  <matplotlib.lines.Line2D at 0x7f84293dca10>,
#  <matplotlib.lines.Line2D at 0x7f84293dcc90>,
#  <matplotlib.lines.Line2D at 0x7f84293dd050>,
#  <matplotlib.lines.Line2D at 0x7f84293dd410>,
#  <matplotlib.lines.Line2D at 0x7f84293dd890>,
#  <matplotlib.lines.Line2D at 0x7f84293ddb10>,
#  <matplotlib.lines.Line2D at 0x7f842936dfd0>,
#  <matplotlib.lines.Line2D at 0x7f84293de250>,
#  <matplotlib.lines.Line2D at 0x7f84293de5d0>,
#  <matplotlib.lines.Line2D at 0x7f84294d6a90>,
#  <matplotlib.lines.Line2D at 0x7f84293ded10>,
#  <matplotlib.lines.Line2D at 0x7f84293df090>,
#  <matplotlib.lines.Line2D at 0x7f84293df450>,
#  <matplotlib.lines.Line2D at 0x7f84293df990>,
#  <matplotlib.lines.Line2D at 0x7f84293dfb90>,
#  <matplotlib.lines.Line2D at 0x7f84293dffd0>,
#  <matplotlib.lines.Line2D at 0x7f84293e4350>,
#  <matplotlib.lines.Line2D at 0x7f84293e4890>,
#  <matplotlib.lines.Line2D at 0x7f84293e4c50>,
#  <matplotlib.lines.Line2D at 0x7f84293350d0>,
#  <matplotlib.lines.Line2D at 0x7f84293e5350>,
#  <matplotlib.lines.Line2D at 0x7f84293e56d0>,
#  <matplotlib.lines.Line2D at 0x7f8429395b90>,
#  <matplotlib.lines.Line2D at 0x7f84293e5e10>,
#  <matplotlib.lines.Line2D at 0x7f84293e61d0>,
#  <matplotlib.lines.Line2D at 0x7f8429366650>,
#  <matplotlib.lines.Line2D at 0x7f84294ee9d0>,
#  <matplotlib.lines.Line2D at 0x7f84293e6c50>,
#  <matplotlib.lines.Line2D at 0x7f84293e6fd0>,
#  <matplotlib.lines.Line2D at 0x7f84293e7350>,
#  <matplotlib.lines.Line2D at 0x7f84293e7710>,
#  <matplotlib.lines.Line2D at 0x7f84294d7bd0>,
#  <matplotlib.lines.Line2D at 0x7f84293e7e50>,
#  <matplotlib.lines.Line2D at 0x7f84293d8350>,
#  <matplotlib.lines.Line2D at 0x7f84293d86d0>,
#  <matplotlib.lines.Line2D at 0x7f84293d8a50>,
#  <matplotlib.lines.Line2D at 0x7f84293e8cd0>,
#  <matplotlib.lines.Line2D at 0x7f84293e9090>,
#  <matplotlib.lines.Line2D at 0x7f84293b9550>,
#  <matplotlib.lines.Line2D at 0x7f84293a18d0>,
#  <matplotlib.lines.Line2D at 0x7f8429371c50>,
#  <matplotlib.lines.Line2D at 0x7f84295f1fd0>,
#  <matplotlib.lines.Line2D at 0x7f84293ea250>,
#  <matplotlib.lines.Line2D at 0x7f84293ea610>,
#  <matplotlib.lines.Line2D at 0x7f84293ea9d0>,
#  <matplotlib.lines.Line2D at 0x7f84293ead90>,
#  <matplotlib.lines.Line2D at 0x7f84293eb150>,
#  <matplotlib.lines.Line2D at 0x7f84293eb690>,
#  <matplotlib.lines.Line2D at 0x7f84293eb890>,
#  <matplotlib.lines.Line2D at 0x7f8429343d50>,
#  <matplotlib.lines.Line2D at 0x7f842a014110>,
#  <matplotlib.lines.Line2D at 0x7f84293ec390>,
#  <matplotlib.lines.Line2D at 0x7f8429340a50>,
#  <matplotlib.lines.Line2D at 0x7f84293ecad0>,
#  <matplotlib.lines.Line2D at 0x7f842933cf90>,
#  <matplotlib.lines.Line2D at 0x7f84293ed210>,
#  <matplotlib.lines.Line2D at 0x7f84293ed5d0>,
#  <matplotlib.lines.Line2D at 0x7f84293ed950>,
#  <matplotlib.lines.Line2D at 0x7f84293bde10>,
#  <matplotlib.lines.Line2D at 0x7f842a08e190>,
#  <matplotlib.lines.Line2D at 0x7f842950e510>,
#  <matplotlib.lines.Line2D at 0x7f84293ee790>,
#  <matplotlib.lines.Line2D at 0x7f84293eeb50>,
#  <matplotlib.lines.Line2D at 0x7f84293eef10>,
#  <matplotlib.lines.Line2D at 0x7f842939f3d0>,
#  <matplotlib.lines.Line2D at 0x7f84293ef650>,
#  <matplotlib.lines.Line2D at 0x7f842941fb10>,
#  <matplotlib.lines.Line2D at 0x7f84293efd90>,
#  <matplotlib.lines.Line2D at 0x7f84293b8290>,
#  <matplotlib.lines.Line2D at 0x7f84293f8510>,
#  <matplotlib.lines.Line2D at 0x7f84293f88d0>,
#  <matplotlib.lines.Line2D at 0x7f8429360d50>,
#  <matplotlib.lines.Line2D at 0x7f84293d9110>]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(all_rays_aber_lens[-1].x, all_rays_aber_lens[-1].y, 'o')
plt.axis('equal')
# Out:
# (-0.473189620088072,
#  -0.4713437132452616,
#  -0.0009200062357094625,
#  0.0009238098207480878)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
